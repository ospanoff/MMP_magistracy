# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
data = np.load('data/dataVMK50_2017.npy')

# %%
def show(img):
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
for

# %%
m = np.mean(data, axis=2)
d = np.std(data, axis=2)

# %%
show(m)

# %%
show((data[..., 0] - m) / d)
